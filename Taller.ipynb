# %% [markdown]
# **Taller1:**
#
# No de Identificación, Nombres, Apellidos, Dirección, Teléfono, Edad, Estado Civil, Número de hijos, Estatura en centímetros, fecha de contratación (Día/mes/año), Sueldo básico, Días Laborados.

# %%
#Numero de identificación
no_id = 1015472368
print(no_id)
#Nombre
nombre = "Claudia"
print(nombre)
#Apellidos
apellido = "Marin"
print(apellido)
#Direccion
direccion = input("Digite su dirección: ")
print(direccion)
#Telefono
telefono = 3223107491
print(telefono)
#Edad
edad = 24
print(edad)
#Estado Civil
estado_civil = input("Estado Civil: ")
print(estado_civil)
#Número de hijos
no_hijos = input("Numero de hijos: ")
print(no_hijos)
#Estatura en centimetros
estatura = "1.60 cm"
print(estatura)
#Empleado
empleado = input("empleado SI o NO: ")
print(empleado)
#Fecha Contratación
fecha_contratacion = input("Digite la fecha de contratación: ")
print(fecha_contratacion)
#Sueldo basico
sueldo_basico = input("Digite su salario: ")
print(sueldo_basico)
#Dias laborados
dias_laborados = input("Dias laborados: ")
print(dias_laborados)
# Out:
# 1015472368
# Claudia
# Marin
# Digite su dirección: casa suba
# casa suba
# 3223107491
# 24
# Estado Civil: casada
# casada
# Numero de hijos: 0
# 0
# 1.60 cm
# empleado SI o NO: SI
# SI
# Digite la fecha de contratación: 22/04/2019
# 22/04/2019
# Digite su salario: 1.200.000
# 1.200.000
# Dias laborados: 720 DIAS
# 720 DIAS

# %% [markdown]
# **Taller 2**
#
# Dando continuidad con la primera entrega del proyecto, en esta oportunidad el estudiante debe realizar las siguientes validaciones utilizando la sentencia condicional IF.
#
# Si el empleado es mayor de 55 años disfrutará de un bono de prepensión correspondiente al 5% de su sueldo básico.
#
# Si el empleado es casado y tiene hijos se le otorgará un paseo cada diciembre
#
# Si el sueldo básico está entre 1.000.000 y 1.500.000 tendrá una comisión del 2% sobre el valor del sueldo; Si el sueldo básico está entre 1.500.001 y 2.000.000 tendrá una comisión del 5% sobre el valor del sueldo; para todos los demás casos no habrá comisión.
#
# Si el empleado trabajó más de 20 días al mes y su sueldo es menor a 1.
# 000.000 tendrá derecho a un bono de alimentación.

# %%
#Numero de identificación
no_id = 1015472368
print(no_id)
#Nombre
nombre = "Claudia"
print(nombre)
#Apellidos
apellido = "Marin"
print(apellido)
#Direccion
#direccion = input("Digite su dirección: ")
direccion = "Cra 94 no. 131"
print(direccion)
#Telefono
telefono = 3223107491
print(telefono)
#Edad
edad = int(input("Digite su edad: "))
print(edad)
#Estado Civil
#estado_civil = input("Estado Civil: ")
estado_civil = "Casada"
print(estado_civil)
#Número de hijos
#no_hijos = input("Numero de hijos: ")
no_hijos = "0"
print(no_hijos)
#Estatura en centimetros
estatura = "1.60 cm"
print(estatura)
#Empleado
empleado = input("empleado SI o NO: ")
print(empleado)
#Fecha Contratación
#fecha_contratacion = input("Digite la fecha de contratación: ")
fecha_contratacion = "19/04/2019"
print(fecha_contratacion)
#Sueldo basico
sueldo_basico = int(input("Digite su salario: "))
print(sueldo_basico)
#Dias laborados
#dias_laborados = input("Dias laborados: ")
dias_laborados = "60"
print(dias_laborados)

if empleado == "SI" and edad > 55:
  bono = sueldo_basico * 0.05
  total = sueldo_basico  + bono
  print("El valor del bono es =${:,.0f} y el total a pagar es= {:,.0f}".format(bono, total))
else: 
  print("No tiene bono, es menor a la edad permitida para el bono, el total a pagar es= ${:,.0f}".format(sueldo_basico))
# Out:
# 1015472368
# Claudia
# Marin
# Cra 94 no. 131
# 3223107491
# Digite su edad: 56
# 56
# Casada
# 0
# 1.60 cm
# empleado SI o NO: SI
# SI
# 19/04/2019
# Digite su salario: 2000000
# 2000000
# 60
# El valor del bono es =$100,000 y el total a pagar es= 2,100,000

# %% [markdown]
# Si el empleado es casado y tiene hijos se le otorgará un paseo cada diciembre

# %%
#Numero de identificación
no_id = 1015472368
print(no_id)
#Nombre
nombre = "Claudia"
print(nombre)
#Apellidos
apellido = "Marin"
print(apellido)
#Direccion
#direccion = input("Digite su dirección: ")
direccion = "Cra 94 no. 131"
print(direccion)
#Telefono
telefono = 3223107491
print(telefono)
#Edad
edad = 24
print(edad)
#Estado Civil
estado_civil = input("Estado Civil: ")
print(estado_civil)
#Número de hijos
no_hijos = int(input("Numero de hijos: "))
print(no_hijos)
#Estatura en centimetros
estatura = "1.60 cm"
print(estatura)
#Empleado
empleado = input("empleado SI o NO: ")
print(empleado)
#Fecha Contratación
#fecha_contratacion = input("Digite la fecha de contratación: ")
fecha_contratacion = "19/04/2019"
print(fecha_contratacion)
#Sueldo basico
#sueldo_basico = input("Digite su salario: ")
sueldo_basico = "3500000"
print(sueldo_basico)
#Dias laborados
#dias_laborados = input("Dias laborados: ")
dias_laborados = "99"
print(dias_laborados)

if estado_civil in "CASADO"   and no_hijos > 0   and empleado in "SI":
  print("El empleado cumple las condiciones para disfrutar de un paseo cada diciembre")
else: 
  print("El empleado NO cumple las condiciones para disfrutar de un paseo cada diciembre")
# Out:
# 1015472368
# Claudia
# Marin
# Cra 94 no. 131
# 3223107491
# 24
# Estado Civil: CASADO
# CASADO
# Numero de hijos: 3
# 3
# 1.60 cm
# empleado SI o NO: NO
# NO
# 19/04/2019
# 3500000
# 99
# El empleado NO cumple las condiciones para disfrutar de un paseo cada diciembre

# %% [markdown]
# Si el sueldo básico está entre 1.000.000 y 1.500.000 tendrá una comisión del 2% sobre el valor del sueldo; Si el sueldo básico está entre 1.500.001 y 2.000.000 tendrá una comisión del 5% sobre el valor del sueldo; para todos los demás casos no habrá comisión.

# %%
#Numero de identificación
no_id = 1015472368
print(no_id)
#Nombre
nombre = "Claudia"
print(nombre)
#Apellidos
apellido = "Marin"
print(apellido)
#Direccion
#direccion = input("Digite su dirección: ")
direccion = "Cra 94 no. 131"
print(direccion)
#Telefono
telefono = 3223107491
print(telefono)
#Edad
edad = 24
print(edad)
#Estado Civil
#estado_civil = input("Estado Civil: ")
estado_civil = "CASADA"
print(estado_civil)
#Número de hijos
#no_hijos = int(input("Numero de hijos: "))
no_hijos = 0
print(no_hijos)
#Estatura en centimetros
estatura = "1.60 cm"
print(estatura)
#Empleado
empleado = input("empleado SI o NO: ")
print(empleado)
#Fecha Contratación
#fecha_contratacion = input("Digite la fecha de contratación: ")
fecha_contratacion = "19/04/2019"
print(fecha_contratacion)
#Sueldo basico
sueldo_basico = float(input("Digite su salario: "))
print(sueldo_basico)
#Dias laborados
#dias_laborados = input("Dias laborados: ")
dias_laborados = "99"
print(dias_laborados)

if empleado == "SI" and sueldo_basico >= 1000000 and sueldo_basico <= 1500000:
  bono1 = sueldo_basico * 0.02
  total = sueldo_basico + bono1
  print("El bono sobre su salario basico es =${:,.0f} y su sueldo total es= ${:,.0f}".format(bono1, total))
elif empleado == "SI" and sueldo_basico >= 1500001 and sueldo_basico <= 2000000:
  bono2 = sueldo_basico * 0.05
  total = sueldo_basico + bono2
  print("El bono sobre su salario basico es =${:,.0f} y su sueldo total es= ${:,.0f}".format(bono2, total))
else:
  print("Usted no cumple con niguna condición para acceder al bono")
# Out:
# 1015472368
# Claudia
# Marin
# Cra 94 no. 131
# 3223107491
# 24
# CASADA
# 0
# 1.60 cm
# empleado SI o NO: SI
# SI
# 19/04/2019
# Digite su salario: 1980000
# 1980000.0
# 99
# El bono sobre su salario basico es =$99,000 y su sueldo total es= 2,079,000

# %% [markdown]
# Si el empleado trabajó más de 20 días al mes y su sueldo es menor a 1. 000.000 tendrá derecho a un bono de alimentación.

# %%
#Numero de identificación
no_id = 1015472368
print(no_id)
#Nombre
nombre = "Claudia"
print(nombre)
#Apellidos
apellido = "Marin"
print(apellido)
#Direccion
#direccion = input("Digite su dirección: ")
direccion = "Cra 94 no. 131"
print(direccion)
#Telefono
telefono = 3223107491
print(telefono)
#Edad
edad = 24
print(edad)
#Estado Civil
#estado_civil = input("Estado Civil: ")
estado_civil = "CASADA"
print(estado_civil)
#Número de hijos
#no_hijos = int(input("Numero de hijos: "))
no_hijos = 0
print(no_hijos)
#Estatura en centimetros
estatura = "1.60 cm"
print(estatura)
#Empleado
empleado = input("empleado SI o NO: ")
print(empleado)
#Fecha Contratación
#fecha_contratacion = input("Digite la fecha de contratación: ")
fecha_contratacion = "19/04/2019"
print(fecha_contratacion)
#Sueldo basico
sueldo_basico = float(input("Digite su salario: "))
print(sueldo_basico)
#Dias laborados
dias_laborados = int(input("Dias laborados: "))
#dias_laborados = "99"
print(dias_laborados)

if empleado == "SI" and sueldo_basico < 1000000 and dias_laborados > 20:
  print("Puede reclamar un bono de alimentación")
else:
  print("Usted no cumple con niguna condición para acceder al bono")
# Out:
# 1015472368
# Claudia
# Marin
# Cra 94 no. 131
# 3223107491
# 24
# CASADA
# 0
# 1.60 cm
# empleado SI o NO: SI
# SI
# 19/04/2019
# Digite su salario: 900000
# 900000.0
# Dias laborados: 21
# 21
# Puede reclamar un bono de alimentación
